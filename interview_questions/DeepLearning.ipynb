# %% [markdown]
# The following ipython notebook are presented with my solutions to deep learning interview questions and any additional information I want to keep to look back on later to better serve my memory.

# %% [markdown]
# ### Chapter 2

# %% [markdown]
# Problem 2.1
#
# *True*, introducing more variables normally generates a model that has a better fit to the data. The drawback to this is model fitting strategy is that one could overfit the model.
